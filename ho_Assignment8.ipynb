# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

df = pd.read_csv('voting_data.csv')
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
print("Decision tree")
df1.replace('y', 1, inplace=True)
df1.replace('n', 0, inplace=True)
df1.replace('?', 2, inplace=True)
df1 = df1.dropna()

x= df1.drop('Class Name', axis=1)
y = df1['Class Name']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.2)
d = DecisionTreeClassifier()
d.fit(xtrain, ytrain)
ypred = d.predict(xtest)
print("Case 1")
print(classification_report(ytest,ypred))


print("------------------------------------------------")


df2.replace('y', 1, inplace=True)
df2.replace('n', 0, inplace=True)
df2.replace('?', np.nan, inplace=True)
df2= df2.dropna()

x= df2.drop('Class Name', axis=1)
y = df2['Class Name']

xtrain1, xtest, ytrain1, ytest = train_test_split(x, y, test_size=.2)
d2 = DecisionTreeClassifier()
d2.fit(xtrain, ytrain)
ypred = d2.predict(xtest)
print("Case 2")
print(classification_report(ytest,ypred))


print("------------------------------------------------")


df3.replace('y', 1, inplace=True)
df3.replace('n', 0, inplace=True)
df3.replace('?', 1, inplace=True)
df3= df3.dropna()

x= df3.drop('Class Name', axis=1)
y = df3['Class Name']

xtrain1, xtest, ytrain1, ytest = train_test_split(x, y, test_size=.2)
d2 = DecisionTreeClassifier()
d2.fit(xtrain, ytrain)
ypred = d2.predict(xtest)
print("Case 2")
print(classification_report(ytest,ypred))
# Out:
# Case 1
#               precision    recall  f1-score   support
#
#     democrat       0.93      0.98      0.95        54
#   republican       0.97      0.88      0.92        33
#
#     accuracy                           0.94        87
#    macro avg       0.95      0.93      0.94        87
# weighted avg       0.94      0.94      0.94        87
#
# ------------------------------------------------
# Case 2
#               precision    recall  f1-score   support
#
#     democrat       0.96      1.00      0.98        23
#   republican       1.00      0.96      0.98        24
#
#     accuracy                           0.98        47
#    macro avg       0.98      0.98      0.98        47
# weighted avg       0.98      0.98      0.98        47
#
# ------------------------------------------------
# Case 2
#               precision    recall  f1-score   support
#
#     democrat       0.96      0.98      0.97        54
#   republican       0.97      0.94      0.95        33
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report




df = pd.read_csv('voting_data.csv')
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()

df1.replace('y', 1, inplace=True)
df1.replace('n', 0, inplace=True)
df1.replace('?', 2, inplace=True)
df1 = df1.dropna()

x= df1.drop('Class Name', axis=1)
y = df1['Class Name']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.2)

nb = MultinomialNB()
nb.fit(xtrain, ytrain)
ypred = nb.predict(xtest)
print(classification_report(ytest, ypred))
print("------------------------------------------------")


df2.replace('y', 1, inplace=True)
df2.replace('n', 0, inplace=True)
df2.replace('?', np.nan, inplace=True)
df2= df2.dropna()

x= df2.drop('Class Name', axis=1)
y = df2['Class Name']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.2)

nb = MultinomialNB()
nb.fit(xtrain, ytrain)
ypred = nb.predict(xtest)
print(classification_report(ytest, ypred))


print("------------------------------------------------")


df3.replace('y', 1, inplace=True)
df3.replace('n', 0, inplace=True)
df3.replace('?', 1, inplace=True)

x= df3.drop('Class Name', axis=1)
y = df['Class Name']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.2)

nb = MultinomialNB()
nb.fit(xtrain, ytrain)
ypred = nb.predict(xtest)
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#     democrat       0.93      0.96      0.94        53
#   republican       0.94      0.88      0.91        34
#
#     accuracy                           0.93        87
#    macro avg       0.93      0.92      0.93        87
# weighted avg       0.93      0.93      0.93        87
#
# ------------------------------------------------
#               precision    recall  f1-score   support
#
#     democrat       0.83      0.96      0.89        26
#   republican       0.94      0.76      0.84        21
#
#     accuracy                           0.87        47
#    macro avg       0.89      0.86      0.87        47
# weighted avg       0.88      0.87      0.87        47
#
# ------------------------------------------------
#               precision    recall  f1-score   support
#
#     democrat       1.00      0.83      0.91        58
#   republican       0.74      1.00      0.85        29
#
# ...

# %%
The clasification algorithim i felt did better was the naive bayes algorithim because i felt like the results was more accurate. The naive bayes algorithim also did better when intances was missing. This dataset is very long and extensive but both algorithims was able to perform well. I did notice that the Decision tree was a good basis in more simplier task but the more information that was given, the results did get generalized more.
